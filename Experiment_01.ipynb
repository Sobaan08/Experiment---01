# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# #**Loading Files**

# %%
df1 = pd.read_csv('Social_Network_Ads.csv')

# %%
df2 = pd.read_csv('student3.csv')
df2
# Out:
#     roll     name class  marks    age
# 0      1     anil    TE   56.77  22.0
# 1      2     amit    TE   59.77  21.0
# 2      3   aniket    BE   76.88  19.0
# 3      4  ajinkya    TE   69.66  20.0
# 4      5     asha    TE   63.28   NaN
# 5      6   ayesha    BE     NaN  20.0
# 6      7     amar    BE   65.34  19.0
# 7      8    Amita    be   68.33  23.0
# 8      9     amol    TE   56.75  20.0
# 9      9     amol    TE   56.75  20.0
# 10    10    anmol    BE   78.66   NaN
# 11    11   surbhi    TE     NaN  23.0
# 12    12    Sujay    TE   74.12  22.0
# 13    13  subhash    be   88.45  21.0
# 14    14   sachin   NaN   59.33  21.0
# 15    15  shalini    TE   63.45  20.0

# %% [markdown]
# #**Merging wo files**

# %%
merged = pd.merge(df1, df2, on='age')
merged
# Out:
#      User ID  Gender  age  EstimatedSalary  Purchased  roll    name class  \
# 0   15624510    Male   19            19000          0     3  aniket    BE
# 1   15624510    Male   19            19000          0     7    amar    BE
# 2   15804002    Male   19            76000          0     3  aniket    BE
# 3   15804002    Male   19            76000          0     7    amar    BE
# 4   15672091  Female   19            21000          0     3  aniket    BE
# ..       ...     ...  ...              ...        ...   ...     ...   ...
# 78  15774179  Female   22            27000          0    12   Sujay    TE
# 79  15684801    Male   22            81000          0     1    anil    TE
# 80  15684801    Male   22            81000          0    12   Sujay    TE
# 81  15762228  Female   22            55000          0     1    anil    TE
# 82  15762228  Female   22            55000          0    12   Sujay    TE
#
#     marks
# 0    76.88
# 1    65.34
# 2    76.88
# 3    65.34
# 4    76.88
# ...

# %% [markdown]
# #**Filtering merged file**

# %%
merged.filter(["User ID"])
# Out:
#      User ID
# 0   15624510
# 1   15624510
# 2   15804002
# 3   15804002
# 4   15672091
# ..       ...
# 78  15774179
# 79  15684801
# 80  15684801
# 81  15762228
# 82  15762228
#
# [83 rows x 1 columns]

# %% [markdown]
# #**Sampling**

# %%
merged.sample(frac = .1)
# Out:
#      User ID  Gender  age  EstimatedSalary  Purchased  roll     name class  \
# 4   15672091  Female   19            21000          0     3   aniket    BE
# 24  15709476    Male   20            49000          0     4  ajinkya    TE
# 8   15807909    Male   19            85000          0     3   aniket    BE
# 27  15709476    Male   20            49000          0     9     amol    TE
# 57  15638963  Female   21            68000          0    14   sachin   NaN
# 37  15767871    Male   20            74000          0     9     amol    TE
# 19  15595228  Female   20            23000          0     4  ajinkya    TE
# 3   15804002    Male   19            76000          0     7     amar    BE
#
#     marks
# 4    76.88
# 24   69.66
# 8    76.88
# 27   56.75
# 57   59.33
# 37   56.75
# 19   69.66
# 3    65.34

# %% [markdown]
# #**Data Inspection**

# %%
df1.head()
df1.info()
df1.describe()
df1.isnull()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   User ID          400 non-null    int64
#  1   Gender           400 non-null    object
#  2   age              400 non-null    int64
#  3   EstimatedSalary  400 non-null    int64
#  4   Purchased        400 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 15.8+ KB
#      User ID  Gender    age  EstimatedSalary  Purchased
# 0      False   False  False            False      False
# 1      False   False  False            False      False
# 2      False   False  False            False      False
# 3      False   False  False            False      False
# 4      False   False  False            False      False
# ..       ...     ...    ...              ...        ...
# 395    False   False  False            False      False
# ...

# %% [markdown]
# #**Drop null values**

# %%
df1.dropna()
# Out:
#       User ID  Gender  age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %% [markdown]
# #**Handeling missing values**

# %%
df2['marks '].fillna(df2['marks '].mean())
# Out:
# 0     56.770000
# 1     59.770000
# 2     76.880000
# 3     69.660000
# 4     63.280000
# 5     66.967143
# 6     65.340000
# 7     68.330000
# 8     56.750000
# 9     56.750000
# 10    78.660000
# 11    66.967143
# 12    74.120000
# 13    88.450000
# 14    59.330000
# 15    63.450000
# Name: marks , dtype: float64

# %%
df2['age'].fillna(df2['age'].mode()[0])
# Out:
# 0     22.0
# 1     21.0
# 2     19.0
# 3     20.0
# 4     20.0
# 5     20.0
# 6     19.0
# 7     23.0
# 8     20.0
# 9     20.0
# 10    20.0
# 11    23.0
# 12    22.0
# 13    21.0
# 14    21.0
# 15    20.0
# Name: age, dtype: float64

# %% [markdown]
# #**Data Transformation**

# %%
df1 = pd.read_csv('Social_Network_Ads.csv')
x = df1[['age','EstimatedSalary']]
scaler = MinMaxScaler()
x_scaled = scaler.fit_transform(x)
x_scaled
# Out:
# array([[0.02380952, 0.02962963],
#        [0.4047619 , 0.03703704],
#        [0.19047619, 0.20740741],
#        [0.21428571, 0.31111111],
#        [0.02380952, 0.45185185],
#        [0.21428571, 0.31851852],
#        [0.21428571, 0.51111111],
#        [0.33333333, 1.        ],
#        [0.16666667, 0.13333333],
#        [0.4047619 , 0.37037037],
#        [0.19047619, 0.48148148],
#        [0.19047619, 0.27407407],
#        [0.04761905, 0.52592593],
#        [0.33333333, 0.02222222],
#        [0.        , 0.4962963 ],
#        [0.26190476, 0.48148148],
#        [0.69047619, 0.07407407],
#        [0.64285714, 0.08148148],
#        [0.66666667, 0.0962963 ],
#        [0.71428571, 0.1037037 ],
#        [0.64285714, 0.05185185],
#        [0.69047619, 0.25185185],
#        [0.71428571, 0.19259259],
#        [0.64285714, 0.05185185],
#        [0.66666667, 0.05925926],
#        [0.69047619, 0.03703704],
#        [0.73809524, 0.0962963 ],
#        [0.69047619, 0.11111111],
# ...

# %%
pd.get_dummies(df1,columns=['Purchased'])
# Out:
#       User ID  Gender  age  EstimatedSalary  Purchased_0  Purchased_1
# 0    15624510    Male   19            19000         True        False
# 1    15810944    Male   35            20000         True        False
# 2    15668575  Female   26            43000         True        False
# 3    15603246  Female   27            57000         True        False
# 4    15804002    Male   19            76000         True        False
# ..        ...     ...  ...              ...          ...          ...
# 395  15691863  Female   46            41000        False         True
# 396  15706071    Male   51            23000        False         True
# 397  15654296  Female   50            20000        False         True
# 398  15755018    Male   36            33000         True        False
# 399  15594041  Female   49            36000        False         True
#
# [400 rows x 6 columns]

# %% [markdown]
# #**Data Integration**

# %%
df_1 = pd.read_csv('Student_5.csv')
df_2 = pd.read_csv('student3.csv')

# %%
merged_data = pd.merge(df_1, df_2, on='roll')
merged_data
# Out:
#     roll   name_x class_x  marks _x  age_x   name_y class_y  marks _y  age_y
# 0      1     anil      TE     56.77   22.0     anil      TE     56.77   22.0
# 1      2     amit      TE     59.77   21.0     amit      TE     59.77   21.0
# 2      3   aniket      BE     76.88   19.0   aniket      BE     76.88   19.0
# 3      4  ajinkya      TE     69.66   20.0  ajinkya      TE     69.66   20.0
# 4      5     asha      TE     63.28    NaN     asha      TE     63.28    NaN
# 5      6   ayesha      BE       NaN   20.0   ayesha      BE       NaN   20.0
# 6      7     amar      BE     65.34   19.0     amar      BE     65.34   19.0
# 7      7     amar      BE     65.34   19.0     amar      BE     65.34   19.0
# 8      8    Amita      be    168.33   23.0    Amita      be     68.33   23.0
# 9      9     amol      TE     56.75   20.0     amol      TE     56.75   20.0
# 10     9     amol      TE     56.75   20.0     amol      TE     56.75   20.0
# ...
